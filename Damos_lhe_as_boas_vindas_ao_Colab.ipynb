# %% [markdown]
# <a href="https://colab.research.google.com/github/bernardoclavilho-creator/ATIVIDADE-2-/blob/main/Damos_lhe_as_boas_vindas_ao_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Entrada do usuário
nome =  input("qual o seu nome: ")
idade = int (input("qual a sua idade: ") )
cidade = (input(" qual a sua cidade: ") )

print(f"Olá {nome}, você tem {idade} anos e mora em {cidade}. seja bem-vindo ao python!")
# Out:
# qual o seu nome: bernardo
# qual a sua idade: 17
#  qual a sua cidade: juiz de fora
# Olá bernardo, você tem 17 anos e mora em juiz de fora. seja bem-vindo ao python!
